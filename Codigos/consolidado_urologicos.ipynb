# %%
import os
import pandas as pd
import numpy as np
import re
from datetime import date, datetime
import warnings
import glob 

# Desactiva las advertencias
warnings.filterwarnings('ignore')

# %%
dir_actual = os.getcwd()
dir_gestoras = os.path.join(dir_actual,'..')

# %%
# Día actual
today = date.today()

# Fecha actual
now = datetime.now()

# Formatear día con ceros a la izquierda si es necesario
day_formatted = "{:02d}".format(today.day)

# Formatear mes con ceros a la izquierda si es necesario
month_formatted = "{:02d}".format(today.month)

# %%
nombre_archivo = f'{today.year}{month_formatted}{day_formatted}_Pacientes_nuevos_vesical.xlsx'  # Nombre del archivo de Excel
ruta_del_archivo = os.path.join(dir_actual, '..','CA UROLOGICOS','Reporte diario casos nuevos',f'{nombre_archivo}')  # index=False para no incluir el índice en el archivo de Excel 
df_existente = pd.read_excel(ruta_del_archivo)

# %%
df_existente = pd.read_excel(ruta_del_archivo)

# %%
df_existente
# Out:
# Empty DataFrame
# Columns: [Problema Oncologico, RUT, DV, Nombre del Paciente, Etapa, Estado, Fecha Próximo Hito, Medico Responsable, Fecha de Comité, Observacion, DIAGNOSTICOS, Telefono Consolidado2, CITAS FUTURAS, MEDICO, Fecha Ultima atencion, Profesional Ultima atencion]
# Index: []

# %%
nombre_archivo = f'{today.year}{month_formatted}{day_formatted}_Pacientes_nuevos_testicular.xlsx'  # Nombre del archivo de Excel
ruta_del_archivo = os.path.join(dir_actual, '..','CA UROLOGICOS','Reporte diario casos nuevos',f'{nombre_archivo}')  # index=False para no incluir el índice en el archivo de Excel 
df_existente_2 = pd.read_excel(ruta_del_archivo)

# %%
df_existente_2
# Out:
#                     Problema Oncologico      RUT DV  \
# 0                    Linfoma en Adultos  3308316  5
# 1  Linfoma en Adultos .{decreto nº 228}  4645275  5
# 2                    Linfoma en Adultos  5133308  K
# 3                    Linfoma en Adultos  7698996  6
#
#                   Nombre del Paciente  Etapa  Estado  Fecha Próximo Hito  \
# 0           ODELIA VALENZUELA SÁNCHEZ    NaN     NaN                 NaN
# 1  LEYTON GÁLVEZ, PEDRO LUIS DE JESÚS    NaN     NaN                 NaN
# 2      LUIS ERNESTO ARELLANO ESPINOZA    NaN     NaN                 NaN
# 3     LUCÍA DEL CARMEN TRUJILLO SACCO    NaN     NaN                 NaN
#
#    Medico Responsable  Fecha de Comité  Observacion  \
# 0                 NaN              NaN          NaN
# 1                 NaN              NaN          NaN
# 2                 NaN              NaN          NaN
# 3                 NaN              NaN          NaN
#
#                                         DIAGNOSTICOS  \
# ...

# %%
nombre_archivo = f'{today.year}{month_formatted}{day_formatted}_Pacientes_nuevos_renal.xlsx'  # Nombre del archivo de Excel
ruta_del_archivo = os.path.join(dir_actual, '..','CA UROLOGICOS','Reporte diario casos nuevos',f'{nombre_archivo}')  # index=False para no incluir el índice en el archivo de Excel 
df_existente_3 = pd.read_excel(ruta_del_archivo)

# %%
df_existente_3
# Out:
#                         Problema Oncologico      RUT  DV  \
# 0                          Mieloma múltiple  5436812   7
# 1  Mieloma múltiple . {Decreto Nro 22/2019}  5983033   3
#
#             Nombre del Paciente  Etapa  Estado  Fecha Próximo Hito  \
# 0  ANGEL ENRIQUE ALIAGA PIZARRO    NaN     NaN                 NaN
# 1     MOYA RUIZ, CARLOS ALBERTO    NaN     NaN                 NaN
#
#    Medico Responsable  Fecha de Comité  Observacion          DIAGNOSTICOS  \
# 0                 NaN              NaN          NaN  ['Mieloma multiple']
# 1                 NaN              NaN          NaN                   NaN
#
#                                Telefono Consolidado2  CITAS FUTURAS  MEDICO  \
# 0                                       97348335/0/-            NaN     NaN
# 1  - / - / 22910312 / 0 / 57521138 / 22910312 / -...            NaN     NaN
#
#    Fecha Ultima atencion  Profesional Ultima atencion
# 0                    NaN                          NaN
# ...

# %%
nombre_archivo = f'{today.year}{month_formatted}{day_formatted}_Pacientes_nuevos_prostata.xlsx'  # Nombre del archivo de Excel
ruta_del_archivo = os.path.join(dir_actual, '..','CA UROLOGICOS','Reporte diario casos nuevos',f'{nombre_archivo}')  # index=False para no incluir el índice en el archivo de Excel 
df_existente_4 = pd.read_excel(ruta_del_archivo)

# %%
consolidado = pd.concat([df_existente, df_existente_2, df_existente_3, df_existente_4])

# %%
consolidado
# Out:
#                         Problema Oncologico      RUT DV  \
# 0                        Linfoma en Adultos  3308316  5
# 1      Linfoma en Adultos .{decreto nº 228}  4645275  5
# 2                        Linfoma en Adultos  5133308  K
# 3                        Linfoma en Adultos  7698996  6
# 0                          Mieloma múltiple  5436812  7
# 1  Mieloma múltiple . {Decreto Nro 22/2019}  5983033  3
#
#                   Nombre del Paciente Etapa Estado Fecha Próximo Hito  \
# 0           ODELIA VALENZUELA SÁNCHEZ   NaN    NaN                NaN
# 1  LEYTON GÁLVEZ, PEDRO LUIS DE JESÚS   NaN    NaN                NaN
# 2      LUIS ERNESTO ARELLANO ESPINOZA   NaN    NaN                NaN
# 3     LUCÍA DEL CARMEN TRUJILLO SACCO   NaN    NaN                NaN
# 0        ANGEL ENRIQUE ALIAGA PIZARRO   NaN    NaN                NaN
# 1           MOYA RUIZ, CARLOS ALBERTO   NaN    NaN                NaN
#
#   Medico Responsable Fecha de Comité Observacion  \
# ...

# %%
nombre_archivo = f'{today.year}{month_formatted}{day_formatted}_Pacientes_nuevos_urologicos.xlsx'  # Nombre del archivo de Excel
consolidado.to_excel(os.path.join(dir_actual, '..','CA UROLOGICOS','Reporte diario casos nuevos',f'{nombre_archivo}'), index=False)  # index=False para no incluir el índice en el archivo de Excel

# %%
nombre_archivo = f'{today.year}{month_formatted}{day_formatted}_ultima_atencion_vesical.xlsx'  # Nombre del archivo de Excel
ruta_del_archivo = os.path.join(dir_actual, '..','CA UROLOGICOS',f'{nombre_archivo}')  # index=False para no incluir el índice en el archivo de Excel 
_df_existente = pd.read_excel(ruta_del_archivo)

# %%
nombre_archivo = f'{today.year}{month_formatted}{day_formatted}_ultima_atencion_testicular.xlsx'  # Nombre del archivo de Excel
ruta_del_archivo = os.path.join(dir_actual, '..','CA UROLOGICOS',f'{nombre_archivo}')  # index=False para no incluir el índice en el archivo de Excel 
_df_existente_2 = pd.read_excel(ruta_del_archivo)

# %%
nombre_archivo = f'{today.year}{month_formatted}{day_formatted}_ultima_atencion_renal.xlsx'  # Nombre del archivo de Excel
ruta_del_archivo = os.path.join(dir_actual, '..','CA UROLOGICOS',f'{nombre_archivo}')  # index=False para no incluir el índice en el archivo de Excel 
_df_existente_3 = pd.read_excel(ruta_del_archivo)

# %%
nombre_archivo = f'{today.year}{month_formatted}{day_formatted}_ultima_atencion_prostata.xlsx'  # Nombre del archivo de Excel
ruta_del_archivo = os.path.join(dir_actual, '..','CA UROLOGICOS',f'{nombre_archivo}')  # index=False para no incluir el índice en el archivo de Excel 
_df_existente_4 = pd.read_excel(ruta_del_archivo)

# %%
consolidado_2 = pd.concat([_df_existente, _df_existente_2, _df_existente_3, _df_existente_4])

# %%
consolidado_2
# Out:
#          RUT Fecha Ultima atencion  \
# 0    5642462            08-10-2022
# 1    4018540            02-09-2023
# 2    5440613            02-03-2022
# 3    5526729            04-12-2022
# 4    6056761            20-12-2022
# ..       ...                   ...
# 398  3576435            04-10-2024
# 399  8996149            22-05-2024
# 400  6097627            05-08-2024
# 401  7486390            03-08-2024
# 402  5436812            17-05-2024
#
#                            Profesional Ultima atencion
# 0    Médico FELIPE ALFONSO PALACIOS CÁRDENAS Contro...
# 1    Médico FELIPE ALFONSO PALACIOS CÁRDENAS Contro...
# 2    Médico BELKYS MERCEDES LINARES Control - Consu...
# 3    Médico BELKYS MERCEDES LINARES Control - Consu...
# 4    Médico FELIPE ALFONSO PALACIOS CÁRDENAS Contro...
# ..                                                 ...
# 398  Médico FELIPE ALFONSO PALACIOS CÁRDENAS Contro...
# 399  Médico FELIPE ALFONSO PALACIOS CÁRDENAS Contro...
# ...

# %%
import pandas
from openpyxl import Workbook
from openpyxl.utils.dataframe import dataframe_to_rows

# %%
wb = Workbook()
ws = wb.active

for r in dataframe_to_rows(consolidado_2, index= False, header = True):
    ws.append(r)

for cell in ws['B'][1:]:
    cell.number_format = 'DD-MM-YYYY'
nombre_archivo = f'{today.year}{month_formatted}{day_formatted}_ultima_atencion_urologicos.xlsx'
wb.save(os.path.join(dir_actual, '..','CA UROLOGICOS',f'{nombre_archivo}'))

# %%
nombre_archivo = f'{today.year}{month_formatted}{day_formatted}_citas_futuras_vesical.xlsx'  # Nombre del archivo de Excel
ruta_del_archivo = os.path.join(dir_actual, '..','CA UROLOGICOS',f'{nombre_archivo}')  # index=False para no incluir el índice en el archivo de Excel 
__df_existente = pd.read_excel(ruta_del_archivo)

# %%
nombre_archivo = f'{today.year}{month_formatted}{day_formatted}_citas_futuras_testicular.xlsx'  # Nombre del archivo de Excel
ruta_del_archivo = os.path.join(dir_actual, '..','CA UROLOGICOS',f'{nombre_archivo}')  # index=False para no incluir el índice en el archivo de Excel 
__df_existente_2 = pd.read_excel(ruta_del_archivo)

# %%
nombre_archivo = f'{today.year}{month_formatted}{day_formatted}_citas_futuras_renal.xlsx'  # Nombre del archivo de Excel
ruta_del_archivo = os.path.join(dir_actual, '..','CA UROLOGICOS',f'{nombre_archivo}')  # index=False para no incluir el índice en el archivo de Excel 
__df_existente_3 = pd.read_excel(ruta_del_archivo)

# %%
nombre_archivo = f'{today.year}{month_formatted}{day_formatted}_citas_futuras_prostata.xlsx'  # Nombre del archivo de Excel
ruta_del_archivo = os.path.join(dir_actual, '..','CA UROLOGICOS',f'{nombre_archivo}')  # index=False para no incluir el índice en el archivo de Excel 
__df_existente_4 = pd.read_excel(ruta_del_archivo)

# %%
consolidado_3 = pd.concat([__df_existente, __df_existente_2, __df_existente_3, __df_existente_4])

# %%
consolidado_3
# Out:
#            RUT NOMBRE_AGENDA ESPECIALIDAD_AGENDA    CITAFECH  CITAHORA  \
# 0      4023493         TAC 2    Imagenología AMB  28-05-2024       930
# 1      4432050      Sala I-4    Imagenología AMB  28-05-2024      1340
# 2      4433849      Sala I-4    Imagenología AMB  28-05-2024      1320
# 3      4433849      Sala I-4    Imagenología AMB  28-05-2024      1310
# 4      4807289      Sala I-4    Imagenología AMB  28-05-2024      1230
# ...        ...           ...                 ...         ...       ...
# 1893   5636179      Sala I-3    Imagenología AMB  21-08-2024      1410
# 1894   5636179      Sala I-3    Imagenología AMB  21-08-2024      1400
# 1895  22889659      Sala I-4    Imagenología AMB  04-10-2024       840
# 1896  22889659      Sala I-4    Imagenología AMB  04-10-2024       830
# 1897   6830435         TAC 2    Imagenología AMB  02-12-2024       900
#
#      ESTADO_CITA                               DESCRIPCION ORIGEN GES_CITA  \
# ...

# %%
wb = Workbook()
ws = wb.active

for r in dataframe_to_rows(consolidado_3, index= False, header = True):
    ws.append(r)

for cell in ws['D'][1:]:
    cell.number_format = 'DD-MM-YYYY'
nombre_archivo = f'{today.year}{month_formatted}{day_formatted}_citas_futuras_hematologicos.xlsx'
wb.save(os.path.join(dir_actual, '..','CA UROLOGICOS',f'{nombre_archivo}'))

# %% [markdown]
# # Eliminar los transitorios

# %%
dir_actual
# Out:
# '\\\\apolo\\Gestion_Oncologica\\SCRIPT'

# %%
patron_sic = os.path.join(dir_actual, '..','CA UROLOGICOS','Reporte diario casos nuevos','*Pacientes_nuevos*')

archivos_sic  = glob.glob(patron_sic)

archivos_ordenados_sic  = sorted(archivos_sic , key=os.path.getmtime, reverse = True)

rutas_archivos_4 = archivos_ordenados_sic[:5]

# %%
rutas_archivos_4
# Out:
# ['\\\\apolo\\Gestion_Oncologica\\SCRIPT\\..\\CA HEMATOLOGICOS\\Reporte diario casos nuevos\\20240701_Pacientes_nuevos_hematologicos.xlsx',
#  '\\\\apolo\\Gestion_Oncologica\\SCRIPT\\..\\CA HEMATOLOGICOS\\Reporte diario casos nuevos\\20240701_Pacientes_nuevos_mieloma.xlsx',
#  '\\\\apolo\\Gestion_Oncologica\\SCRIPT\\..\\CA HEMATOLOGICOS\\Reporte diario casos nuevos\\20240701_Pacientes_nuevos_linfoma.xlsx',
#  '\\\\apolo\\Gestion_Oncologica\\SCRIPT\\..\\CA HEMATOLOGICOS\\Reporte diario casos nuevos\\20240701_Pacientes_nuevos_leucemia.xlsx']

# %%
patron_sic = os.path.join(dir_actual, '..','CA UROLOGICOS','*citas_futuras*')

archivos_sic  = glob.glob(patron_sic)

archivos_ordenados_sic  = sorted(archivos_sic , key=os.path.getmtime, reverse = True)

rutas_archivos_5 = archivos_ordenados_sic[:5]

# %%
rutas_archivos_5
# Out:
# ['\\\\apolo\\Gestion_Oncologica\\SCRIPT\\..\\CA HEMATOLOGICOS\\20240701_citas_futuras_hematologicos.xlsx',
#  '\\\\apolo\\Gestion_Oncologica\\SCRIPT\\..\\CA HEMATOLOGICOS\\20240701_citas_futuras_mieloma.xlsx',
#  '\\\\apolo\\Gestion_Oncologica\\SCRIPT\\..\\CA HEMATOLOGICOS\\20240701_citas_futuras_linfoma.xlsx',
#  '\\\\apolo\\Gestion_Oncologica\\SCRIPT\\..\\CA HEMATOLOGICOS\\20240701_citas_futuras_leucemia.xlsx']

# %%
patron_sic = os.path.join(dir_actual, '..','CA UROLOGICOS','*ultima_atencion*')

archivos_sic  = glob.glob(patron_sic)

archivos_ordenados_sic  = sorted(archivos_sic , key=os.path.getmtime, reverse = True)

rutas_archivos_6 = archivos_ordenados_sic[:5]

# %%
rutas_archivos_6
# Out:
# ['\\\\apolo\\Gestion_Oncologica\\SCRIPT\\..\\CA HEMATOLOGICOS\\20240701_ultima_atencion_hematologicos.xlsx',
#  '\\\\apolo\\Gestion_Oncologica\\SCRIPT\\..\\CA HEMATOLOGICOS\\20240701_ultima_atencion_mieloma.xlsx',
#  '\\\\apolo\\Gestion_Oncologica\\SCRIPT\\..\\CA HEMATOLOGICOS\\20240701_ultima_atencion_linfoma.xlsx',
#  '\\\\apolo\\Gestion_Oncologica\\SCRIPT\\..\\CA HEMATOLOGICOS\\20240701_ultima_atencion_leucemia.xlsx']

# %%
for ruta in rutas_archivos_4:
    if '_urologicos' not in ruta:
        try:
            if os.path.isfile(ruta):
                os.remove(ruta)
                print(f'voy a eliminar {ruta}')
        except Exception as e:
            print(f'Error al eliminar {ruta}. Razón {e}')
# Out:
# voy a eliminar \\apolo\Gestion_Oncologica\SCRIPT\..\CA HEMATOLOGICOS\Reporte diario casos nuevos\20240701_Pacientes_nuevos_mieloma.xlsx
# voy a eliminar \\apolo\Gestion_Oncologica\SCRIPT\..\CA HEMATOLOGICOS\Reporte diario casos nuevos\20240701_Pacientes_nuevos_linfoma.xlsx
# voy a eliminar \\apolo\Gestion_Oncologica\SCRIPT\..\CA HEMATOLOGICOS\Reporte diario casos nuevos\20240701_Pacientes_nuevos_leucemia.xlsx

# %%
for ruta in rutas_archivos_5:
    if '_urologicos' not in ruta:
        try:
            if os.path.isfile(ruta):
                os.remove(ruta)
                print(f'voy a eliminar {ruta}')
        except Exception as e:
            print(f'Error al eliminar {ruta}. Razón {e}')
# Out:
# voy a eliminar \\apolo\Gestion_Oncologica\SCRIPT\..\CA HEMATOLOGICOS\20240701_citas_futuras_mieloma.xlsx
# voy a eliminar \\apolo\Gestion_Oncologica\SCRIPT\..\CA HEMATOLOGICOS\20240701_citas_futuras_linfoma.xlsx
# voy a eliminar \\apolo\Gestion_Oncologica\SCRIPT\..\CA HEMATOLOGICOS\20240701_citas_futuras_leucemia.xlsx

# %%
for ruta in rutas_archivos_6:
    if '_urologicos' not in ruta:
        try:
            if os.path.isfile(ruta):
                os.remove(ruta)
                print(f'voy a eliminar {ruta}')
        except Exception as e:
            print(f'Error al eliminar {ruta}. Razón {e}')
# Out:
# voy a eliminar \\apolo\Gestion_Oncologica\SCRIPT\..\CA HEMATOLOGICOS\20240701_ultima_atencion_mieloma.xlsx
# voy a eliminar \\apolo\Gestion_Oncologica\SCRIPT\..\CA HEMATOLOGICOS\20240701_ultima_atencion_linfoma.xlsx
# voy a eliminar \\apolo\Gestion_Oncologica\SCRIPT\..\CA HEMATOLOGICOS\20240701_ultima_atencion_leucemia.xlsx
